# %% [markdown]
# # Import Library

# %%
#Import Library
import pandas as pd
import numpy as np
import joblib
import json

# %% [markdown]
# # Data Loading

# %%
# Data Loading
inference = pd.read_csv('inference.csv')
inference.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 20 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   aluminium    20 non-null     float64
#  1   ammonia      20 non-null     float64
#  2   arsenic      20 non-null     float64
#  3   barium       20 non-null     float64
#  4   cadmium      20 non-null     float64
#  5   chloramine   20 non-null     float64
#  6   chromium     20 non-null     float64
#  7   copper       20 non-null     float64
#  8   flouride     20 non-null     float64
#  9   bacteria     20 non-null     float64
#  10  viruses      20 non-null     float64
#  11  lead         20 non-null     float64
#  12  nitrates     20 non-null     float64
#  13  nitrites     20 non-null     float64
#  14  mercury      20 non-null     float64
#  15  perchlorate  20 non-null     float64
#  16  radium       20 non-null     float64
#  17  selenium     20 non-null     float64
# ...

# %% [markdown]
# # Model Inference

# %%
# Model Inference
model = joblib.load('model.pkl')
with open('feature.json','r') as file:
    feature = json.load(file)

# %%
# Model Inference
inference.insert(0,'predict',model.predict(inference[feature]))
inference.head()
# Out:
#    predict  aluminium    ammonia   arsenic    barium   cadmium  chloramine  \
# 0        1   1.622879  26.279195  0.090189  2.274966  0.111389    6.116953
# 1        0   4.994968   2.701083  0.496109  3.861637  0.126211    7.140916
# 2        0   2.501366   1.931529  1.000560  2.242159  0.087517    8.396383
# 3        0   4.988676  25.264127  0.753805  0.463400  0.015748    4.945155
# 4        0   3.875402   7.262514  0.148173  1.532552  0.123301    1.402945
#
#    chromium    copper  flouride  ...   viruses      lead  nitrates  nitrites  \
# 0  0.040624  0.258421  0.910313  ...  0.262517  0.079315  7.353736  0.693994
# 1  0.041334  1.241741  0.798281  ...  0.510009  0.074478  8.535131  2.435186
# 2  0.631149  0.147653  1.419956  ...  0.679878  0.076712  8.643542  2.028039
# 3  0.086887  1.892387  0.430212  ...  0.648720  0.158412  3.822359  0.518683
# 4  0.175526  0.010548  0.656294  ...  0.883588  0.136143  1.686715  1.538230
#
# ...
